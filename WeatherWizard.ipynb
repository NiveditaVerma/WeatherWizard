# %% [markdown]
# #WeatherWizard: A weather prediction ML model

# %% [markdown]
# Downloading the data from NOAA (National Ocenic and Atmospheric Administration)

# %%
import pandas as pd

weather = pd.read_csv("/content/data.csv", index_col="DATE")

# %%
weather
# Out:
#                 STATION         NAME  PRCP  SNWD  TAVG  TMAX  TMIN
# DATE
# 1975-03-20  IN018103100  PATIALA, IN   NaN   NaN  66.0  86.0  57.0
# 1975-03-24  IN018103100  PATIALA, IN   NaN   NaN  75.0   NaN  55.0
# 1975-04-06  IN018103100  PATIALA, IN   NaN   NaN  80.0   NaN  72.0
# 1975-04-08  IN018103100  PATIALA, IN   NaN   NaN  76.0  86.0   NaN
# 1975-04-09  IN018103100  PATIALA, IN   NaN   NaN  77.0  86.0  59.0
# ...                 ...          ...   ...   ...   ...   ...   ...
# 2023-08-12  IN018103100  PATIALA, IN   NaN   NaN  89.0  97.0  83.0
# 2023-08-13  IN018103100  PATIALA, IN   NaN   NaN  89.0  96.0  82.0
# 2023-08-14  IN018103100  PATIALA, IN   NaN   NaN  85.0  95.0  81.0
# 2023-08-15  IN018103100  PATIALA, IN   NaN   NaN  87.0  97.0  81.0
# 2023-08-16  IN018103100  PATIALA, IN   0.0   NaN  89.0  98.0  82.0
#
# [16443 rows x 7 columns]
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def value_plot(df, y, figscale=1):
#   from matplotlib import pyplot as plt
#   df[y].plot(kind='line', figsize=(8 * figscale, 4 * figscale), title=y)
#   plt.gca().spines[['top', 'right']].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = value_plot(weather, *['PRCP'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def value_plot(df, y, figscale=1):
#   from matplotlib import pyplot as plt
#   df[y].plot(kind='line', figsize=(8 * figscale, 4 * figscale), title=y)
#   plt.gca().spines[['top', 'right']].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = value_plot(weather, *['SNWD'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def value_plot(df, y, figscale=1):
#   from matplotlib import pyplot as plt
#   df[y].plot(kind='line', figsize=(8 * figscale, 4 * figscale), title=y)
#   plt.gca().spines[['top', 'right']].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = value_plot(weather, *['TAVG'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def value_plot(df, y, figscale=1):
#   from matplotlib import pyplot as plt
#   df[y].plot(kind='line', figsize=(8 * figscale, 4 * figscale), title=y)
#   plt.gca().spines[['top', 'right']].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = value_plot(weather, *['TMAX'], **{})
# chart
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def histogram(df, colname, num_bins=20, figscale=1):
#   from matplotlib import pyplot as plt
#   df[colname].plot(kind='hist', bins=num_bins, title=colname, figsize=(8*figscale, 4*figscale))
#   plt.gca().spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = histogram(weather, *['PRCP'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def histogram(df, colname, num_bins=20, figscale=1):
#   from matplotlib import pyplot as plt
#   df[colname].plot(kind='hist', bins=num_bins, title=colname, figsize=(8*figscale, 4*figscale))
#   plt.gca().spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = histogram(weather, *['SNWD'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def histogram(df, colname, num_bins=20, figscale=1):
#   from matplotlib import pyplot as plt
#   df[colname].plot(kind='hist', bins=num_bins, title=colname, figsize=(8*figscale, 4*figscale))
#   plt.gca().spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = histogram(weather, *['TAVG'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def histogram(df, colname, num_bins=20, figscale=1):
#   from matplotlib import pyplot as plt
#   df[colname].plot(kind='hist', bins=num_bins, title=colname, figsize=(8*figscale, 4*figscale))
#   plt.gca().spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = histogram(weather, *['TMAX'], **{})
# chart
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def scatter_plots(df, colname_pairs, figscale=1, alpha=.8):
#   from matplotlib import pyplot as plt
#   plt.figure(figsize=(len(colname_pairs) * 10 * figscale, 10 * figscale))
#   for plot_i, (x_colname, y_colname) in enumerate(colname_pairs, start=1):
#     ax = plt.subplot(1, len(colname_pairs), plot_i)
#     df.plot(kind='scatter', x=x_colname, y=y_colname, s=(32 * figscale), alpha=alpha, ax=ax)
#     ax.spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = scatter_plots(weather, *[[['PRCP', 'SNWD'], ['SNWD', 'TAVG'], ['TAVG', 'TMAX'], ['TMAX', 'TMIN']]], **{})
# chart

# %% [markdown]
# Checking the ratio of null values in each column

# %%
weather.apply(pd.isnull).sum()/weather.shape[0]
# Out:
# STATION    0.000000
# NAME       0.000000
# PRCP       0.454357
# SNWD       0.999818
# TAVG       0.014231
# TMAX       0.134647
# TMIN       0.293864
# dtype: float64

# %% [markdown]
# Picking out core parameters as per documentation and renaming them

# %%
core_weather = weather[["PRCP", "SNWD", "TMAX", "TMIN"]].copy()
core_weather.columns = ["precip", "snow_depth", "temp_max", "temp_min"]

# %%
core_weather.apply(pd.isnull).sum()/core_weather.shape[0]
# Out:
# precip      0.454357
# temp_max    0.134647
# temp_min    0.293864
# dtype: float64

# %%
core_weather["snow_depth"].value_counts()
# Out:
# 3.1    2
# 7.1    1
# Name: snow_depth, dtype: int64

# %%
del core_weather["snow_depth"]

# %%
core_weather[pd.isnull(core_weather["precip"])]
# Out:
#             precip  temp_max  temp_min
# DATE
# 1975-03-20     NaN      86.0      57.0
# 1975-03-24     NaN       NaN      55.0
# 1975-04-06     NaN       NaN      72.0
# 1975-04-08     NaN      86.0       NaN
# 1975-04-09     NaN      86.0      59.0
# ...            ...       ...       ...
# 2023-08-11     NaN      97.0      80.0
# 2023-08-12     NaN      97.0      83.0
# 2023-08-13     NaN      96.0      82.0
# 2023-08-14     NaN      95.0      81.0
# 2023-08-15     NaN      97.0      81.0
#
# [7471 rows x 3 columns]

# %%
core_weather["precip"].value_counts() / core_weather.shape[0]
# Out:
# 0.00     0.409658
# 0.02     0.010217
# 0.04     0.009427
# 0.08     0.008818
# 0.12     0.008210
#            ...
# 7.76     0.000061
# 0.73     0.000061
# 1.60     0.000061
# 10.42    0.000061
# 5.31     0.000061
# Name: precip, Length: 305, dtype: float64

# %% [markdown]
# Filling the missing values as 0

# %%
core_weather["precip"] = core_weather["precip"].fillna(0)

# %%
core_weather.apply(pd.isnull).sum()
# Out:
# precip         0
# temp_max    2214
# temp_min    4832
# dtype: int64

# %%
core_weather[pd.isnull(core_weather["temp_min"])]
# Out:
#             precip  temp_max  temp_min
# DATE
# 1975-04-08    0.00      86.0       NaN
# 1975-04-12    0.00      95.0       NaN
# 1975-04-14    0.00      95.0       NaN
# 1975-04-20    0.00       NaN       NaN
# 1975-04-22    0.00       NaN       NaN
# ...            ...       ...       ...
# 2023-07-27    0.00      95.0       NaN
# 2023-07-30    0.00      94.0       NaN
# 2023-08-02    0.00      98.0       NaN
# 2023-08-06    0.12      97.0       NaN
# 2023-08-09    0.00      96.0       NaN
#
# [4832 rows x 3 columns]

# %%
core_weather = core_weather.fillna(method="ffill")

# %%
core_weather.apply(pd.isnull).sum()
# Out:
# precip      0
# temp_max    0
# temp_min    0
# dtype: int64

# %%
core_weather.dtypes
# Out:
# precip      float64
# temp_max    float64
# temp_min    float64
# dtype: object

# %%
core_weather.index
# Out:
# Index(['1975-03-20', '1975-03-24', '1975-04-06', '1975-04-08', '1975-04-09',
#        '1975-04-12', '1975-04-13', '1975-04-14', '1975-04-15', '1975-04-17',
#        ...
#        '2023-08-07', '2023-08-08', '2023-08-09', '2023-08-10', '2023-08-11',
#        '2023-08-12', '2023-08-13', '2023-08-14', '2023-08-15', '2023-08-16'],
#       dtype='object', name='DATE', length=16443)

# %% [markdown]
# Converting date from object datatype to datetime

# %%
core_weather.index = pd.to_datetime(core_weather.index)

# %%
core_weather.index
# Out:
# DatetimeIndex(['1975-03-20', '1975-03-24', '1975-04-06', '1975-04-08',
#                '1975-04-09', '1975-04-12', '1975-04-13', '1975-04-14',
#                '1975-04-15', '1975-04-17',
#                ...
#                '2023-08-07', '2023-08-08', '2023-08-09', '2023-08-10',
#                '2023-08-11', '2023-08-12', '2023-08-13', '2023-08-14',
#                '2023-08-15', '2023-08-16'],
#               dtype='datetime64[ns]', name='DATE', length=16443, freq=None)

# %%
core_weather.index.year
# Out:
# Int64Index([1975, 1975, 1975, 1975, 1975, 1975, 1975, 1975, 1975, 1975,
#             ...
#             2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023],
#            dtype='int64', name='DATE', length=16443)

# %% [markdown]
# Checking for any data that has not been received

# %%
core_weather.apply(lambda x:(x==9999)).sum()
# Out:
# precip      0
# temp_max    0
# temp_min    0
# dtype: int64

# %% [markdown]
# Analysing the data

# %%
core_weather[["temp_max", "temp_min"]].plot()
# Out:
# <Axes: xlabel='DATE'>

# %%
core_weather.index.year.value_counts().sort_index()
# Out:
# 1975    102
# 1976     15
# 1977    365
# 1978    365
# 1979    317
# 1980    366
# 1981    365
# 1982    365
# 1983    365
# 1984    366
# 1985    326
# 1986    317
# 1987    354
# 1988    325
# 1989    319
# 1990    269
# 1991    343
# 1992    352
# 1993    291
# 1994    318
# 1995    312
# 1996    342
# 1997    329
# 1998    348
# 1999    351
# 2000    362
# 2001    363
# 2002    360
# 2003    363
# 2004    361
# 2005    360
# 2006    362
# 2007    356
# 2008    364
# 2009    361
# 2010    357
# 2011    358
# 2012    366
# 2013    365
# 2014    365
# 2015    365
# 2016    363
# 2017    362
# 2018    364
# 2019    364
# 2020    366
# 2021    361
# 2022    360
# 2023    228
# Name: DATE, dtype: int64

# %%
core_weather["precip"].plot()
# Out:
# <Axes: xlabel='DATE'>

# %% [markdown]
# Year-wise rain count

# %%
core_weather.groupby(core_weather.index.year).sum()["precip"]
# Out:
# DATE
# 1975      0.00
# 1976      0.00
# 1977     96.64
# 1978     79.53
# 1979     13.06
# 1980     96.22
# 1981     65.76
# 1982    101.89
# 1983    114.35
# 1984     72.83
# 1985     20.81
# 1986     19.56
# 1987      7.74
# 1988     27.33
# 1989     17.85
# 1990     19.00
# 1991     26.26
# 1992     23.96
# 1993     13.31
# 1994     27.69
# 1995     37.41
# 1996     26.10
# 1997     20.78
# 1998     29.14
# 1999     17.73
# 2000     24.73
# 2001     14.10
# 2002     15.84
# 2003     24.30
# 2004     23.06
# 2005     19.32
# 2006     11.88
# 2007     13.52
# 2008     45.40
# 2009     18.48
# 2010     34.12
# 2011     28.07
# 2012     13.22
# 2013     25.55
# 2014     20.01
# 2015     29.18
# 2016     13.91
# 2017     29.99
# 2018     31.03
# 2019     30.88
# 2020     29.43
# 2021     25.37
# 2022     17.44
# 2023     24.88
# Name: precip, dtype: float64

# %%
core_weather.groupby(core_weather.index.year).apply(lambda x: x["precip"].sum()).plot()
# Out:
# <Axes: xlabel='DATE'>

# %% [markdown]
# Training Machine learning model

# %%
core_weather["target"] = core_weather.shift(-1)["temp_max"]

# %%
core_weather
# Out:
#             precip  temp_max  temp_min  target
# DATE
# 1975-03-20     0.0      86.0      57.0    86.0
# 1975-03-24     0.0      86.0      55.0    86.0
# 1975-04-06     0.0      86.0      72.0    86.0
# 1975-04-08     0.0      86.0      72.0    86.0
# 1975-04-09     0.0      86.0      59.0    95.0
# ...            ...       ...       ...     ...
# 2023-08-12     0.0      97.0      83.0    96.0
# 2023-08-13     0.0      96.0      82.0    95.0
# 2023-08-14     0.0      95.0      81.0    97.0
# 2023-08-15     0.0      97.0      81.0    98.0
# 2023-08-16     0.0      98.0      82.0     NaN
#
# [16443 rows x 4 columns]

# %% [markdown]
# Removing last row, because the target value cannot be predicted for that

# %%
core_weather = core_weather.iloc[:-1,:].copy()

# %%
core_weather
# Out:
#             precip  temp_max  temp_min  target
# DATE
# 1975-03-20     0.0      86.0      57.0    86.0
# 1975-03-24     0.0      86.0      55.0    86.0
# 1975-04-06     0.0      86.0      72.0    86.0
# 1975-04-08     0.0      86.0      72.0    86.0
# 1975-04-09     0.0      86.0      59.0    95.0
# ...            ...       ...       ...     ...
# 2023-08-11     0.0      97.0      80.0    97.0
# 2023-08-12     0.0      97.0      83.0    96.0
# 2023-08-13     0.0      96.0      82.0    95.0
# 2023-08-14     0.0      95.0      81.0    97.0
# 2023-08-15     0.0      97.0      81.0    98.0
#
# [16442 rows x 4 columns]

# %%
from sklearn.linear_model import Ridge

reg = Ridge(alpha=.1)

# %%
predictors = ["precip", "temp_max", "temp_min"]

# %%
train = core_weather.loc[:"1995-12-31"]
test = core_weather.loc["1996-01-01":]

# %%
train
# Out:
#             precip  temp_max  temp_min  target
# DATE
# 1975-03-20     0.0      86.0      57.0    86.0
# 1975-03-24     0.0      86.0      55.0    86.0
# 1975-04-06     0.0      86.0      72.0    86.0
# 1975-04-08     0.0      86.0      72.0    86.0
# 1975-04-09     0.0      86.0      59.0    95.0
# ...            ...       ...       ...     ...
# 1995-12-27     0.0      66.0      46.0    66.0
# 1995-12-28     0.0      66.0      43.0    71.0
# 1995-12-29     0.0      71.0      43.0    67.0
# 1995-12-30     0.0      67.0      44.0    67.0
# 1995-12-31     0.0      67.0      46.0    70.0
#
# [6517 rows x 4 columns]

# %%
test
# Out:
#             precip  temp_max  temp_min  target
# DATE
# 1996-01-01     0.0      70.0      46.0    70.0
# 1996-01-02     0.0      70.0      46.0    69.0
# 1996-01-03     0.0      69.0      46.0    70.0
# 1996-01-04     0.0      70.0      40.0    69.0
# 1996-01-05     0.0      69.0      40.0    69.0
# ...            ...       ...       ...     ...
# 2023-08-11     0.0      97.0      80.0    97.0
# 2023-08-12     0.0      97.0      83.0    96.0
# 2023-08-13     0.0      96.0      82.0    95.0
# 2023-08-14     0.0      95.0      81.0    97.0
# 2023-08-15     0.0      97.0      81.0    98.0
#
# [9925 rows x 4 columns]

# %%
reg.fit(train[predictors], train["target"])
# Out:
# Ridge(alpha=0.1)

# %%
predictions = reg.predict(test[predictors])

# %%
from sklearn.metrics import mean_squared_error

mean_squared_error(test["target"], predictions)
# Out:
# 8.788417344466318

# %% [markdown]
# Evaluating the model

# %%
combined = pd.concat([test["target"], pd.Series(predictions, index=test.index)], axis=1)
combined.columns = ["actual", "predictions"]

# %%
combined
# Out:
#             actual  predictions
# DATE
# 1996-01-01    70.0    70.536565
# 1996-01-02    69.0    70.536565
# 1996-01-03    70.0    69.637847
# 1996-01-04    69.0    70.160646
# 1996-01-05    69.0    69.261928
# ...            ...          ...
# 2023-08-11    97.0    96.932159
# 2023-08-12    96.0    97.120119
# 2023-08-13    95.0    96.158748
# 2023-08-14    97.0    95.197376
# 2023-08-15    98.0    96.994812
#
# [9925 rows x 2 columns]
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def value_plot(df, y, figscale=1):
#   from matplotlib import pyplot as plt
#   df[y].plot(kind='line', figsize=(8 * figscale, 4 * figscale), title=y)
#   plt.gca().spines[['top', 'right']].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = value_plot(combined, *['actual'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def value_plot(df, y, figscale=1):
#   from matplotlib import pyplot as plt
#   df[y].plot(kind='line', figsize=(8 * figscale, 4 * figscale), title=y)
#   plt.gca().spines[['top', 'right']].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = value_plot(combined, *['predictions'], **{})
# chart
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def histogram(df, colname, num_bins=20, figscale=1):
#   from matplotlib import pyplot as plt
#   df[colname].plot(kind='hist', bins=num_bins, title=colname, figsize=(8*figscale, 4*figscale))
#   plt.gca().spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = histogram(combined, *['actual'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def histogram(df, colname, num_bins=20, figscale=1):
#   from matplotlib import pyplot as plt
#   df[colname].plot(kind='hist', bins=num_bins, title=colname, figsize=(8*figscale, 4*figscale))
#   plt.gca().spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = histogram(combined, *['predictions'], **{})
# chart
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def scatter_plots(df, colname_pairs, figscale=1, alpha=.8):
#   from matplotlib import pyplot as plt
#   plt.figure(figsize=(len(colname_pairs) * 10 * figscale, 10 * figscale))
#   for plot_i, (x_colname, y_colname) in enumerate(colname_pairs, start=1):
#     ax = plt.subplot(1, len(colname_pairs), plot_i)
#     df.plot(kind='scatter', x=x_colname, y=y_colname, s=(32 * figscale), alpha=alpha, ax=ax)
#     ax.spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = scatter_plots(combined, *[[['actual', 'predictions']]], **{})
# chart

# %%
combined.plot()
# Out:
# <Axes: xlabel='DATE'>

# %%
reg.coef_
# Out:
# array([0.11939555, 0.89871798, 0.0626532 ])

# %%
core_weather["month_max"] = core_weather["temp_max"].rolling(30).mean()

core_weather["month_day_max"] = core_weather["month_max"] / core_weather["temp_max"]

core_weather["max_min"] = core_weather["temp_max"] / core_weather["temp_min"]

# %% [markdown]
# Creating a function to make predictions

# %%
def create_predictions(predictors, core_weather, reg):
    train = core_weather.loc[:"2020-12-31"]
    test = core_weather.loc["2021-01-01":]

    reg.fit(train[predictors], train["target"])
    predictions = reg.predict(test[predictors])

    error = mean_squared_error(test["target"], predictions)

    combined = pd.concat([test["target"], pd.Series(predictions, index=test.index)], axis=1)
    combined.columns = ["actual", "predictions"]
    return error, combined

# %% [markdown]
# Adding rolling means

# %%
core_weather["month_max"]=core_weather["temp_max"].rolling(30).mean()

# %%
core_weather["month_day_max"]=core_weather["month_max"]/core_weather["temp_max"]

# %%
core_weather["max_min"]=core_weather["temp_max"]/core_weather["temp_min"]

# %%
predictors=["precip","temp_max","temp_min","month_max","month_day_max","max_min"]

# %% [markdown]
# Removing the first 30 null values

# %%
core_weather=core_weather.iloc[30:,:].copy()

# %%
error, combined = create_predictions(predictors, core_weather, reg)
error
# Out:
# 9.433201147149855

# %%
combined.plot()
# Out:
# <Axes: xlabel='DATE'>

# %%
core_weather["monthly_avg"] = core_weather["temp_max"].groupby(core_weather.index.month).apply(lambda x: x.expanding(1).mean())
core_weather["day_of_year_avg"] = core_weather["temp_max"].groupby(core_weather.index.dayofyear).apply(lambda x: x.expanding(1).mean())
# Out:
# <ipython-input-64-36ea2d0c3e04>:1: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   core_weather["monthly_avg"] = core_weather["temp_max"].groupby(core_weather.index.month).apply(lambda x: x.expanding(1).mean())
# <ipython-input-64-36ea2d0c3e04>:2: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   core_weather["day_of_year_avg"] = core_weather["temp_max"].groupby(core_weather.index.dayofyear).apply(lambda x: x.expanding(1).mean())

# %% [markdown]
# Running model diagnosis

# %%
error, combined = create_predictions(predictors + ["monthly_avg", "day_of_year_avg"], core_weather, reg)
error
# Out:
# 9.169020419293657

# %%
reg.coef_
# Out:
# array([-0.10527339,  0.7305882 ,  0.01352377, -1.7256786 ,  0.74408833,
#         0.06517069,  0.19696147])

# %%
core_weather.corr()["target"]
# Out:
# precip             0.000337
# temp_max           0.966338
# temp_min           0.829794
# target             1.000000
# month_max          0.879243
# month_day_max     -0.337472
# max_min           -0.385026
# monthly_avg        0.909048
# day_of_year_avg    0.929821
# Name: target, dtype: float64

# %%
combined["diff"] = (combined["actual"] - combined["predictions"]).abs()

# %%
combined.sort_values("diff", ascending=False).head(10)
# Out:
#             actual  predictions       diff
# DATE
# 2022-05-23    87.0   104.046428  17.046428
# 2022-06-17    85.0    99.608620  14.608620
# 2021-05-18    92.0   106.526823  14.526823
# 2023-05-24    93.0   107.205313  14.205313
# 2021-01-04    76.0    61.967228  14.032772
# 2021-10-17    82.0    95.498726  13.498726
# 2021-04-26   105.0    92.304394  12.695606
# 2022-12-20    59.0    70.856010  11.856010
# 2023-07-08    82.0    93.822392  11.822392
# 2021-06-09   111.0    99.410224  11.589776

# %% [raw]
# # Next steps
#
# * Predict weather for entire next week versus a single day
# * Try data from multiple close-by weather stations over a region
# * Use more of the predictors in the data file
# * Create more predictors (ratios, daily averages, etc)
# * Try different algorithms
# * Setup backtesting to make predictions for all years (versus just 2021)
